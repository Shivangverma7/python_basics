# %% [markdown]
# ## __Markdown__
# ![](https://raw.githubusercontent.com/github/explore/main/topics/markdown/markdown.png)

# %% [markdown]
# Heading ,
#
# shift + Enter to run/execute

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# ### Points & Subpoints in markdown
# `Operators`
#
# - Arithmetic
#     - subpoint
#     - subpoint
# - Assignment
# - Comparison
# - Logical

# %% [markdown]
# ### __BOLD__
#
# **This is bold text**
# __This is bold text__

# %% [markdown]
# ### _ITALIC_
# *This is italic text*
# _This is italic text_

# %% [markdown]
# ### ___BOLD & ITALIC___
#
# ***Bold and Italic***
# ___Bold and Italic___

# %% [markdown]
# ### STRIKETHROUGH
# ~~Scratch this~~

# %% [markdown]
# ### BACKSLASH ESCAPE
# \# Not a header

# %% [markdown]
# ### BLOCKQUOTES
# > BLOCKQUOTES

# %% [markdown]
# ### NESTED BLOCK QUOTING
# > some text
# >> and then some more text
# >>> and then some more

# %% [markdown]
# ### PARAGRAPHS
# Hello World!
# We are learning Markdown.

# %% [markdown]
# ### Horizontal Lines
#
# ---
# ___
# ***

# %% [markdown]
# ### Ordered List
# 1. Cheese
# 2. Carrot
# 3. Coconut

# %% [markdown]
# ### Unordered List
# - Cheese
# - Carrot
# - Coconut

# %% [markdown]
# ### STANDARD LINKS (WITH MOUSE-OVER TITLES)
# [click me](https://en.wikipedia.org "Wikipedia")

# %% [markdown]
# ### REFERENCE-STYLE LINKS
#
# This is [a reference][]
#
#
# [a reference]: https://en.wikipedia.org "Wikipedia"

# %% [markdown]
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
