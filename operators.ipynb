# %%
a = 30
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 50
# 10
# 600
# 1.5
# 1
# 10
# 348678440100000000000000000000

# %%
a+=3 # sameas a = a + 3
print(a)
a-=3 # sameas a = a - 3
print(a)
# Out:
# 39
# 36

# %%
x = 10 
y= 7
z = 11
x>y and x>z
# Out:
# False

# %%
x = 10 
y= 7
z = 11
x>y or x>z
# Out:
# True

# %%
x = 10 
y= 7
z = 11
not(x>y and x>z)
# Out:
# True

# %%
# Identity Operator - is /is not,,EX- x is 
# Membership Operator in / not in
list = [1,2, 3, 4, 6, 7,]
6 in list
# Out:
# True

# %%
list = [1,2, 3, 4, 6, 7,]
5 in list
# Out:
# False
