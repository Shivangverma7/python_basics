# %% [markdown]
# ### __Conditional Statements__
# ___

# %% [markdown]
# `Types of Conditions and their statements`
# - Single Condition
#     - if + else
# - Multiple Conditions
#     - if
#     - else
#     - nested if

# %%
marks = 85
if marks >= 90:
    print('A+')
if marks >= 75:
    print('A')
if marks >= 60:
    print('B')
if marks < 60:
    print('fail')
# Out:
# A
# B

# %%
marks = 85
if marks >= 90:
    print('A+')
elif marks >= 75:
    print('A')
elif marks >= 60:
    print('B')
elif marks < 60:
    print('fail')
else:
    print('Invalid marks')
# Out:
# A

# %%
age =21 
if age <= 18:
    print(" You are Eligible to Vote")
else:
    print("You are not Eligible for Voting")
# Out:
# You are not Eligible for Voting

# %%
age =21 
if age >= 18:
    print(" You are Eligible to Vote")
else:
    print("You are not Eligible for Voting")
# Out:
#  You are Eligible to Vote

# %%
num = int(input("enter a number : "))
if num % 2 == 1:
    print('Even' )
else:
    print('odd')
# Out:
# odd

# %%
num = int(input("enter a number : "))
if num >= 0:
    print('Positive')
else:
    print('Negative')
# Out:
# Positive

# %%
char = input("enter a character:  ")
if char in 'aeiouAEIOU':
    print(f'{char}is a Vowel')
else:
    print(f'{char} is a Consonant')
# Out:
# b is a Consonant

# %%
a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if a == b == c:
    print("The triangle is Equilateral")
elif a == b or b == c or a == c:
    print("The triangle is Isosceles")
else:
    print("The triangle is neither Equilateral nor Isosceles")
# Out:
# The triangle is Isosceles

# %%
# Input sides of the square
side1 = float(input("Enter first side of square: "))
side2 = float(input("Enter second side of square: "))

if side1 == side2:
    print("The sides are equal. It is a square.")
else:
    print("The sides are not equal. It is not a square.")
# Out:
# The sides are equal. It is a square.
